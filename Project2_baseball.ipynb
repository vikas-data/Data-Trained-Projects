# %% [markdown]
# # Baseball-ML-Project
# Baseball case study
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success.There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts,Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W)
#
# -- General Approach: For predicting the number of wins a baseball team will attain -- based on the given input features, a linear regression approach is neccessary.

# %%
# import essential libraries :
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the baseball dataset :
data=pd.read_csv('baseball.csv')

# %%
# lets check the first five records of the given dataset :
data.head(10)
# Out:
#    Wins  Runs  At Bat  Hits  Doubles  Triples  HomeRuns  Walks  Strikeouts  \
# 0    95   724    5575  1497      300       42       139    383         973
# 1    83   696    5467  1349      277       44       156    439        1264
# 2    81   669    5439  1395      303       29       141    533        1157
# 3    76   622    5533  1381      260       27       136    404        1231
# 4    74   689    5605  1515      289       49       151    455        1259
# 5    93   891    5509  1480      308       17       232    570        1151
# 6    87   764    5567  1397      272       19       212    554        1227
# 7    81   713    5485  1370      246       20       217    418        1331
# 8    80   644    5485  1383      278       32       167    436        1310
# 9    78   748    5640  1495      294       33       161    478        1148
#
#    Stolen Bases  Runs Allowed  Earned Runs   ERA  Complete Games  Shutouts  \
# ...

# %%
# lets check the last five records of the given dataset :
data.tail(10)
# Out:
#     Wins  Runs  At Bat  Hits  Doubles  Triples  HomeRuns  Walks  Strikeouts  \
# 20    90   683    5527  1351      295       17       177    488        1290
# 21    83   703    5428  1363      265       13       177    539        1344
# 22    71   613    5463  1420      236       40       120    375        1150
# 23    67   573    5420  1361      251       18       100    471        1107
# 24    63   626    5529  1374      272       37       130    387        1274
# 25    92   667    5385  1346      263       26       187    563        1258
# 26    84   696    5565  1486      288       39       136    457        1159
# 27    79   720    5649  1494      289       48       154    490        1312
# 28    74   650    5457  1324      260       36       148    426        1327
# 29    68   737    5572  1479      274       49       186    388        1283
#
#     Stolen Bases  Runs Allowed  Earned Runs   ERA  Complete Games  Shutouts  \
# ...

# %%
# shape of the dataset (rows, columns) :
data.shape
# Out:
# (30, 17)

# %%
# information of the dataset :
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wins            30 non-null     int64
#  1   Runs            30 non-null     int64
#  2   At Bat          30 non-null     int64
#  3   Hits            30 non-null     int64
#  4   Doubles         30 non-null     int64
#  5   Triples         30 non-null     int64
#  6   HomeRuns        30 non-null     int64
#  7   Walks           30 non-null     int64
#  8   Strikeouts      30 non-null     int64
#  9   Stolen Bases    30 non-null     int64
#  10  Runs Allowed    30 non-null     int64
#  11  Earned Runs     30 non-null     int64
#  12  ERA             30 non-null     float64
#  13  Complete Games  30 non-null     int64
#  14  Shutouts        30 non-null     int64
#  15  Saves           30 non-null     int64
#  16  Errors          30 non-null     int64
# dtypes: float64(1), int64(16)
# ...

# %%
# check column names :
data.columns
# Out:
# Index(['Wins', 'Runs', 'At Bat', 'Hits', 'Doubles', 'Triples', 'HomeRuns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'ERA', 'Complete Games', 'Shutouts', 'Saves', 'Errors  '],
#       dtype='object')

# %%
# lets check is their any null values present in the given dataset :
data.isnull().sum()
# Out:
# Wins              0
# Runs              0
# At Bat            0
# Hits              0
# Doubles           0
# Triples           0
# HomeRuns          0
# Walks             0
# Strikeouts        0
# Stolen Bases      0
# Runs Allowed      0
# Earned Runs       0
# ERA               0
# Complete Games    0
# Shutouts          0
# Saves             0
# Errors            0
# dtype: int64

# %%
# check the null values by using seaborn heatmap function (visulization technique) :
sns.heatmap(data.isnull())
plt.show()

# %%
# Stastictical analysis :
data.describe()
# Out:
#              Wins        Runs       At Bat         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    HomeRuns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
# lets check the frequency of the given features by histogram :
data.hist(figsize=(14,10))
plt.show()

# %%
sns.pairplot(data)

# %%
# check the skewness in the given dataset :
data.skew()
# Out:
# Wins              0.047089
# Runs              1.200786
# At Bat            0.183437
# Hits              0.670254
# Doubles          -0.230650
# Triples           0.129502
# HomeRuns          0.516441
# Walks             0.158498
# Strikeouts       -0.156065
# Stolen Bases      0.479893
# Runs Allowed      0.045734
# Earned Runs       0.058710
# ERA               0.053331
# Complete Games    0.736845
# Shutouts          0.565790
# Saves             0.657524
# Errors            0.890132
# dtype: float64

# %%
# we use loop for removing the skewnwss :
for i in data.columns:
    if data.skew().loc[i]>0.55:
        data[i]=np.log1p(data[i])

# %%
# lets check once again skewness :
data.skew()
# Out:
# Wins              0.047089
# Runs              0.744813
# At Bat            0.183437
# Hits              0.628584
# Doubles          -0.230650
# Triples           0.129502
# HomeRuns          0.516441
# Walks             0.158498
# Strikeouts       -0.156065
# Stolen Bases      0.479893
# Runs Allowed      0.045734
# Earned Runs       0.058710
# ERA               0.053331
# Complete Games   -0.325962
# Shutouts         -0.589640
# Saves             0.163057
# Errors            0.632916
# dtype: float64

# %%
for i in data.columns:
    if data.skew().loc[i]>0.55:
        data[i]=np.log1p(data[i])

# %%
data.skew()
# Out:
# Wins              0.047089
# Runs              0.686947
# At Bat            0.183437
# Hits              0.623445
# Doubles          -0.230650
# Triples           0.129502
# HomeRuns          0.516441
# Walks             0.158498
# Strikeouts       -0.156065
# Stolen Bases      0.479893
# Runs Allowed      0.045734
# Earned Runs       0.058710
# ERA               0.053331
# Complete Games   -0.325962
# Shutouts         -0.589640
# Saves             0.163057
# Errors            0.584066
# dtype: float64

# %%
for i in data.columns:
    if data.skew().loc[i]>0.55:
        data[i]=np.log1p(data[i])

# %%
data.skew()
# Out:
# Wins              0.047089
# Runs              0.667934
# At Bat            0.183437
# Hits              0.621789
# Doubles          -0.230650
# Triples           0.129502
# HomeRuns          0.516441
# Walks             0.158498
# Strikeouts       -0.156065
# Stolen Bases      0.479893
# Runs Allowed      0.045734
# Earned Runs       0.058710
# ERA               0.053331
# Complete Games   -0.325962
# Shutouts         -0.589640
# Saves             0.163057
# Errors            0.565896
# dtype: float64

# %%
# check the outliers from the dataset :
from scipy.stats import zscore
z_score=abs(zscore(data))
print(data.shape)
data_final=data.loc[(z_score<3).all(axis=1)]
print(data_final.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
# Univariate analysis :
sns.distplot(data['Wins'])

# %%
# Univariate analysis :
sns.distplot(data['Runs'])

# %%
sns.distplot(data['At Bat'])

# %%
sns.distplot(data['Hits'])

# %%
# Univariate analysis :
sns.boxplot(data['Doubles'])

# %%
# Univariate analysis :
sns.boxplot(data['Triples'])

# %%
#checking correlation of data
dfr=data.corr()
dfr
# Out:
#           Y Test      Pred
# Y Test  1.000000  0.650376
# Pred    0.650376  1.000000

# %%
plt.figure(figsize=(14,10))
sns.heatmap(dfr,annot=True,cmap='RdYlBu')
plt.show()

# %%
# splitting the data into input and output(X and y) :
X=data_final.drop('Wins',axis=1)
y=data_final['Wins']

# %%
X.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %%
# Scaling the dataset :
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(X)
x=pd.DataFrame(x,columns=X.columns)

# %%
x.shape
# Out:
# (29, 16)

# %%
x.head()
# Out:
#        Runs    At Bat      Hits   Doubles   Triples  HomeRuns     Walks  \
# 0  0.951123  0.830084  1.721335  1.556538  1.010845 -0.765863 -1.536359
# 1  0.360950 -0.702831 -0.951607  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.235176 -1.100253 -0.085799  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.343608  0.233951 -0.345758 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.209042  1.255894  2.025415  0.908319  1.704094 -0.353293 -0.197495
#
#    Strikeouts  Stolen Bases  Runs Allowed  Earned Runs       ERA  \
# 0   -2.727623      0.905953     -0.664514    -0.511148 -0.511388
# 1    0.121896     -0.585315      0.154638     0.232161  0.238952
# 2   -0.925866      0.116458     -0.678397    -0.754153 -0.643801
# 3   -0.201246     -0.673037      0.168522     0.089217  0.040333
# 4    0.072935     -0.015124      1.584683     1.561540  1.496876
#
#    Complete Games  Shutouts     Saves  Errors
# 0       -0.240415 -0.722413  1.554812 -0.425590
# ...

# %%
# importing the scikit learn library train_test_split :
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
# lets check the shape of the data (Xtest, Xtrain, ytrain, ytest) :
print('shape of X_train:',X_train.shape)
print('shape of X_test:',X_test.shape)
print('shape of y_train:',y_train.shape)
print('shape of y_test:',y_test.shape)
# Out:
# shape of X_train: (23, 16)
# shape of X_test: (6, 16)
# shape of y_train: (23,)
# shape of y_test: (6,)

# %% [markdown]
# # LinearRegression

# %%
# model selection :
from sklearn import linear_model ## importing required libraries from skit-learn :
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),X,y,cv=10,scoring='r2').mean()
# Out:
# -3.1025045025651954

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
pred=lr.predict(X_test)
pred
# Out:
# array([76.95354051, 82.88325699, 79.04801133, 58.92905083, 79.0109658 ,
#        79.36520394])

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 6.305834315166824
# MSE: 59.66969721941421
# RMSE: 7.724616315352771

# %%
plt.scatter(x=y_test,y=pred)

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train,y_train)
pred=dtr.predict(X_test)

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('Y-Test')
plt.ylabel('Predicted-Y')
# Out:
# Text(0, 0.5, 'Predicted-Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 10.0
# MSE: 126.33333333333333
# RMSE: 11.239810200058244

# %% [markdown]
# # RandomForestRegressor

# %% [markdown]
# from sklearn.ensemble import RandomForestRegressor rdr = RandomForestRegressor() rdr.fit(X_train,y_train) pred=rdr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 10.0
# MSE: 126.33333333333333
# RMSE: 11.239810200058244

# %%
sns.distplot((y_test-pred),bins=50)

# %%
data = pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#     Y Test  Pred
# 28      74  81.0
# 17      97  90.0
# 13      76  64.0
# 23      67  63.0
# 9       78  68.0

# %% [markdown]
# #We will go with LinearRegression

# %%
import joblib
joblib.dump(lr,'Baseball')
# Out:
# ['Baseball']

# %% [markdown]
# # Conclusion

# %% [markdown]
# #1) These problem we have solved by Regresion (LinearRegression) as told in the above problem statement.
# #2) We have done EDA process, Feature Engineering, Model Selection, finding the right model.
# #3) Our observation is that LinearRegression is best as it gives less RMSE score.
# #4) Also we applied multiple algorithms. 5) Saving the model.
# #Thank You!!
